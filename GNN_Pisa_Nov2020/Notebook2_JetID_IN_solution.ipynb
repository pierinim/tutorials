# %% [markdown]
# # Training a Jet Tagging with **Interaction Networks**
#
# ---
# In this notebook, we perform a Jet identification task using a graph-based multiclass classifier with INs.
#
# The problem consists in identifying a given jet as a quark, a gluon, a W, a Z, or a top,
# based on a jet image, i.e., a 2D histogram of the transverse momentum ($p_T$) deposited in each of 100x100
# bins of a square window of the ($\eta$, $\phi$) plane, centered along the jet axis.
#
# For details on the physics problem, see https://arxiv.org/pdf/1804.06913.pdf
#
# For details on the dataset, see Notebook1
#
# ---

# %%
import os
import h5py
import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
from torch.autograd.variable import *
import torch.optim as optim

# %%
# %matplotlib inline

# %% [markdown]
# # Preparation of the training and validation samples
#
# ---
# In order to import the dataset, we now
# - clone the dataset repository (to import the data in Colab)
# - load the h5 files in the data/ repository
# - extract the data we need: a target and jetImage
#
# To type shell commands, we start the command line with !

# %%
! git clone https://github.com/pierinim/tutorials.git
! ls tutorials/Data/JetDataset/
# Out:
# fatal: destination path 'tutorials' already exists and is not an empty directory.
# jetImage_7_100p_0_10000.h5     jetImage_7_100p_50000_60000.h5
# jetImage_7_100p_10000_20000.h5 jetImage_7_100p_60000_70000.h5
# jetImage_7_100p_30000_40000.h5 jetImage_7_100p_70000_80000.h5
# jetImage_7_100p_40000_50000.h5 jetImage_7_100p_80000_90000.h5

# %%
target = np.array([])
jetList = np.array([])
# we cannot load all data on Colab. So we just take a few files
datafiles = ['tutorials/Data/JetDataset/jetImage_7_100p_30000_40000.h5',
           'tutorials/Data/JetDataset/jetImage_7_100p_60000_70000.h5',
            'tutorials/Data/JetDataset/jetImage_7_100p_50000_60000.h5',
            'tutorials/Data/JetDataset/jetImage_7_100p_10000_20000.h5',
            'tutorials/Data/JetDataset/jetImage_7_100p_0_10000.h5']
# if you are running locallt, you can use the full dataset doing
# for fileIN in glob.glob("tutorials/HiggsSchool/data/*h5"):
for fileIN in datafiles:
    print("Appending %s" %fileIN)
    f = h5py.File(fileIN)
    # for pT, eta, phi
    myJetList = np.array(f.get("jetConstituentList")[:,:,[5,8,11]])
    # for px, py, pz
    #myJetList = np.array(f.get("jetConstituentList")[:,:,[0,1,2]])
    mytarget = np.array(f.get('jets')[0:,-6:-1])
    jetList = np.concatenate([jetList, myJetList], axis=0) if jetList.size else myJetList
    target = np.concatenate([target, mytarget], axis=0) if target.size else mytarget
    del myJetList, mytarget
    f.close()
print(target.shape, jetList.shape)
# Out:
# Appending tutorials/Data/JetDataset/jetImage_7_100p_30000_40000.h5
# Appending tutorials/Data/JetDataset/jetImage_7_100p_60000_70000.h5
# Appending tutorials/Data/JetDataset/jetImage_7_100p_50000_60000.h5
# Appending tutorials/Data/JetDataset/jetImage_7_100p_10000_20000.h5
# Appending tutorials/Data/JetDataset/jetImage_7_100p_0_10000.h5
# (50000, 5) (50000, 100, 3)

# %%
# pytorch Cross Entropy doesn't support one-hot encoding
target = np.argmax(target, axis=1)
# the dataset is N_jets x N_particles x N_features
# the IN wants N_jets x N_features x N_particles
jetList = np.swapaxes(jetList, 1, 2)

# %% [markdown]
# The dataset consists of 50K with up to 100 particles in each jet. These 100 particles have been used to fill the 100x100 jet images.
#
# ---
#
# We now shuffle the data, splitting them into a training and a validation dataset with 2:1 ratio

# %%
nParticle = 30
jetList = jetList[:,:,:nParticle]
print(jetList.shape)
# Out:
# (50000, 3, 30)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(jetList, target, test_size=0.33)
print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)
del jetList, target
# Out:
# (33500, 3, 30) (16500, 3, 30) (33500,) (16500,)

# %%
# check if a GPU is available. Otherwise run on CPU
device = 'cpu'
args_cuda = torch.cuda.is_available()
if args_cuda: device = "cuda"

# %%
# Convert dataset to pytorch
X_train = Variable(torch.FloatTensor(X_train)).to(device)
X_val = Variable(torch.FloatTensor(X_val)).to(device)
y_train = Variable(torch.LongTensor(y_train).long()).to(device)
y_val = Variable(torch.LongTensor(y_val).long()).to(device)

# %% [markdown]
# # Building the IN model

# %%
import itertools

class GraphNet(nn.Module):
    def __init__(self):
        super(GraphNet, self).__init__()
        self.P = 3 # number of features
        self.N = nParticle # number of particles
        self.Nr = self.N * (self.N - 1)
        self.De = 8 # dimensionality of De learned representation
        self.Do = 8 # number of engineered features
        self.n_targets = 5 # number of target classes
        self.assign_matrices() # build Rr and Rs

        # build netwok
        self.hidden = 10
        self.fr1 = nn.Linear(2 * self.P, self.hidden)
        self.fr2 = nn.Linear(self.hidden, self.hidden)
        self.fr3 = nn.Linear(self.hidden, self.De)
        self.fo1 = nn.Linear(self.P + self.De, self.hidden)
        self.fo2 = nn.Linear(self.hidden, self.hidden)
        self.fo3 = nn.Linear(self.hidden, self.Do)
        self.fc1 = nn.Linear(self.Do, self.hidden)
        self.fc2 = nn.Linear(self.hidden, self.hidden)
        self.fc3 = nn.Linear(self.hidden, self.n_targets)
             
    def assign_matrices(self):
        self.Rr = torch.zeros(self.N, self.Nr)
        self.Rs = torch.zeros(self.N, self.Nr)
        receiver_sender_list = [i for i in itertools.product(range(self.N), range(self.N)) if i[0]!=i[1]]
        for i, (r, s) in enumerate(receiver_sender_list):
            self.Rr[r, i] = 1
            self.Rs[s, i] = 1
        self.Rr = Variable(self.Rr)
        self.Rs = Variable(self.Rs)

    def forward(self, x):
        Orr = self.tmul(x, self.Rr)
        Ors = self.tmul(x, self.Rs)
        B = torch.cat([Orr, Ors], 1)
        ### First MLP ###
        B = torch.transpose(B, 1, 2).contiguous()
        B = nn.functional.relu(self.fr1(B.view(-1, 2 * self.P)))
        B = nn.functional.relu(self.fr2(B))
        E = nn.functional.relu(self.fr3(B).view(-1, self.Nr, self.De))
        del B
        E = torch.transpose(E, 1, 2).contiguous()
        Ebar = self.tmul(E, torch.transpose(self.Rr, 0, 1).contiguous())
        del E
        C = torch.cat([x, Ebar], 1)
        del Ebar
        C = torch.transpose(C, 1, 2).contiguous()
        ### Second MLP ###
        C = nn.functional.relu(self.fo1(C.view(-1, self.P + self.De)))
        C = nn.functional.relu(self.fo2(C))
        O = nn.functional.relu(self.fo3(C).view(-1, self.N, self.Do))
        del C
        # sum over constituents
        O = torch.sum(O,1)
        ### Classification MLP ###
        N = nn.functional.relu(self.fc1(O.view(-1, self.Do)))
        N = nn.functional.relu(self.fc2(N))
        del O
        N = self.fc3(N)
        return N

    def tmul(self, x, y):  #Takes (I * J * K)(K * L) -> I * J * L 
        x_shape = x.size()
        y_shape = y.size()
        return torch.mm(x.view(-1, x_shape[2]), y).view(-1, x_shape[1], y_shape[1])

def get_sample(training, target, choice):
    target_vals = np.argmax(target, axis = 1)
    ind, = np.where(target_vals == choice)
    chosen_ind = np.random.choice(ind, 50000)
    return training[chosen_ind], target[chosen_ind]

# %% [markdown]
# ## Training

# %%
n_epochs = 300
batch_size = 100
patience =  10

# %%
gnn = GraphNet()
gnn.to(device)
loss = nn.CrossEntropyLoss()
optimizer = optim.Adam(gnn.parameters(), lr = 0.0001)

loss_train = np.zeros(n_epochs)
acc_train = np.zeros(n_epochs)
loss_val = np.zeros(n_epochs)
acc_val = np.zeros(n_epochs)
for i in range(n_epochs):
    print("Epoch %s" % i)
    for j in range(0, X_train.size()[0], batch_size):
        optimizer.zero_grad()
        out = gnn(X_train[j:j + batch_size,:,:])
        target = y_train[j:j + batch_size]
        l = loss(out, target)
        l.backward()
        optimizer.step()
        loss_train[i] += l.cpu().data.numpy()*batch_size
    loss_train[i] = loss_train[i]/X_train.shape[0]
    #acc_train[i] = stats(predicted, Y_val)
    #### val loss & accuracy
    for j in range(0, X_val.size()[0], batch_size):
        out_val = gnn(X_val[j:j + batch_size])
        target_val =  y_val[j:j + batch_size]
        
        l_val = loss(out_val,target_val)
        loss_val[i] += l_val.cpu().data.numpy()*batch_size
    loss_val[i] = loss_val[i]/X_val.shape[0]
    print("Training   Loss: %f" %l.cpu().data.numpy())
    print("Validation Loss: %f" %l_val.cpu().data.numpy())
    if all(loss_val[max(0, i - patience):i] > min(np.append(loss_val[0:max(0, i - patience)], 200))) and i > patience:
        print("Early Stopping")
        break
    print
# Out:
# Epoch 0
# Training   Loss: 1.585930
# Validation Loss: 1.581979
# Epoch 1
# Training   Loss: 1.464135
# Validation Loss: 1.456512
# Epoch 2
# Training   Loss: 1.444936
# Validation Loss: 1.436243
# Epoch 3
# Training   Loss: 1.437727
# Validation Loss: 1.422909
# Epoch 4
# Training   Loss: 1.429657
# Validation Loss: 1.422964
# Epoch 5
# Training   Loss: 1.425260
# Validation Loss: 1.411103
# Epoch 6
# Training   Loss: 1.424669
# Validation Loss: 1.401849
# Epoch 7
# Training   Loss: 1.426191
# Validation Loss: 1.392467
# Epoch 8
# Training   Loss: 1.427341
# Validation Loss: 1.380121
# Epoch 9
# Training   Loss: 1.427552
# Validation Loss: 1.375289
# Epoch 10
# Training   Loss: 1.428142
# Validation Loss: 1.368384
# Epoch 11
# Training   Loss: 1.428591
# Validation Loss: 1.361646
# Epoch 12
# Training   Loss: 1.428838
# Validation Loss: 1.354960
# Epoch 13
# Training   Loss: 1.429137
# Validation Loss: 1.351515
# Epoch 14
# Training   Loss: 1.429341
# Validation Loss: 1.345540
# Epoch 15
# Training   Loss: 1.430220
# Validation Loss: 1.342386
# Epoch 16
# Training   Loss: 1.429672
# Validation Loss: 1.338314
# Epoch 17
# Training   Loss: 1.428224
# Validation Loss: 1.333993
# Epoch 18
# Training   Loss: 1.427482
# Validation Loss: 1.331850
# Epoch 19
# Training   Loss: 1.426915
# Validation Loss: 1.331444
# Epoch 20
# Training   Loss: 1.425543
# Validation Loss: 1.326553
# Epoch 21
# Training   Loss: 1.424708
# Validation Loss: 1.322304
# Epoch 22
# Training   Loss: 1.424420
# Validation Loss: 1.319402
# Epoch 23
# Training   Loss: 1.425691
# Validation Loss: 1.317176
# Epoch 24
# Training   Loss: 1.426419
# Validation Loss: 1.316099
# Epoch 25
# Training   Loss: 1.425665
# Validation Loss: 1.314745
# Epoch 26
# Training   Loss: 1.426680
# Validation Loss: 1.315503
# Epoch 27
# Training   Loss: 1.424974
# Validation Loss: 1.314347
# Epoch 28
# Training   Loss: 1.425779
# Validation Loss: 1.312305
# Epoch 29
# Training   Loss: 1.429453
# Validation Loss: 1.313480
# Epoch 30
# Training   Loss: 1.428911
# Validation Loss: 1.311251
# Epoch 31
# Training   Loss: 1.431033
# Validation Loss: 1.313030
# Epoch 32
# Training   Loss: 1.429627
# Validation Loss: 1.315280
# Epoch 33
# Training   Loss: 1.417482
# Validation Loss: 1.309842
# Epoch 34
# Training   Loss: 1.416346
# Validation Loss: 1.310164
# Epoch 35
# Training   Loss: 1.412948
# Validation Loss: 1.308207
# Epoch 36
# Training   Loss: 1.421145
# Validation Loss: 1.307210
# Epoch 37
# Training   Loss: 1.412032
# Validation Loss: 1.303877
# Epoch 38
# Training   Loss: 1.411762
# Validation Loss: 1.301389
# Epoch 39
# Training   Loss: 1.410734
# Validation Loss: 1.298182
# Epoch 40
# Training   Loss: 1.405653
# Validation Loss: 1.295576
# Epoch 41
# Training   Loss: 1.403198
# Validation Loss: 1.299125
# Epoch 42
# Training   Loss: 1.400939
# Validation Loss: 1.293867
# Epoch 43
# Training   Loss: 1.397543
# Validation Loss: 1.299892
# Epoch 44
# Training   Loss: 1.396027
# Validation Loss: 1.299596
# Epoch 45
# Training   Loss: 1.396962
# Validation Loss: 1.304737
# Epoch 46
# Training   Loss: 1.394053
# Validation Loss: 1.302705
# Epoch 47
# Training   Loss: 1.392714
# Validation Loss: 1.306302
# Epoch 48
# Training   Loss: 1.381502
# Validation Loss: 1.301933
# Epoch 49
# Training   Loss: 1.376590
# Validation Loss: 1.300404
# Epoch 50
# Training   Loss: 1.379020
# Validation Loss: 1.300811
# Epoch 51
# Training   Loss: 1.373753
# Validation Loss: 1.298035
# Epoch 52
# Training   Loss: 1.377407
# Validation Loss: 1.296785
# Epoch 53
# Training   Loss: 1.372628
# Validation Loss: 1.294811
# Epoch 54
# Training   Loss: 1.370074
# Validation Loss: 1.293992
# Epoch 55
# Training   Loss: 1.364833
# Validation Loss: 1.291064
# Epoch 56
# Training   Loss: 1.360198
# Validation Loss: 1.291819
# Epoch 57
# Training   Loss: 1.361051
# Validation Loss: 1.291344
# Epoch 58
# Training   Loss: 1.359528
# Validation Loss: 1.292373
# Epoch 59
# Training   Loss: 1.356962
# Validation Loss: 1.292453
# Epoch 60
# Training   Loss: 1.352004
# Validation Loss: 1.286540
# Epoch 61
# Training   Loss: 1.352891
# Validation Loss: 1.288867
# Epoch 62
# Training   Loss: 1.350334
# Validation Loss: 1.288247
# Epoch 63
# Training   Loss: 1.349412
# Validation Loss: 1.289764
# Epoch 64
# Training   Loss: 1.347990
# Validation Loss: 1.290925
# Epoch 65
# Training   Loss: 1.344395
# Validation Loss: 1.288661
# Epoch 66
# Training   Loss: 1.339661
# Validation Loss: 1.288690
# Epoch 67
# Training   Loss: 1.344989
# Validation Loss: 1.290204
# Epoch 68
# Training   Loss: 1.342050
# Validation Loss: 1.291319
# Epoch 69
# Training   Loss: 1.341333
# Validation Loss: 1.290934
# Epoch 70
# Training   Loss: 1.337679
# Validation Loss: 1.290324
# Epoch 71
# Training   Loss: 1.339911
# Validation Loss: 1.290791
# Epoch 72
# Training   Loss: 1.340006
# Validation Loss: 1.290092
# Epoch 73
# Training   Loss: 1.339537
# Validation Loss: 1.290343
# Epoch 74
# Training   Loss: 1.338592
# Validation Loss: 1.289533
# Epoch 75
# Training   Loss: 1.334068
# Validation Loss: 1.286946
# Epoch 76
# Training   Loss: 1.331907
# Validation Loss: 1.286017
# Epoch 77
# Training   Loss: 1.330998
# Validation Loss: 1.282762
# Epoch 78
# Training   Loss: 1.331122
# Validation Loss: 1.285610
# Epoch 79
# Training   Loss: 1.327919
# Validation Loss: 1.285911
# Epoch 80
# Training   Loss: 1.328389
# Validation Loss: 1.284956
# Epoch 81
# Training   Loss: 1.325895
# Validation Loss: 1.281592
# Epoch 82
# Training   Loss: 1.328492
# Validation Loss: 1.284313
# Epoch 83
# Training   Loss: 1.327876
# Validation Loss: 1.282880
# Epoch 84
# Training   Loss: 1.327294
# Validation Loss: 1.281786
# Epoch 85
# Training   Loss: 1.326132
# Validation Loss: 1.281519
# Epoch 86
# Training   Loss: 1.326730
# Validation Loss: 1.279805
# Epoch 87
# Training   Loss: 1.324989
# Validation Loss: 1.282180
# Epoch 88
# Training   Loss: 1.329700
# Validation Loss: 1.283334
# Epoch 89
# Training   Loss: 1.329694
# Validation Loss: 1.282491
# Epoch 90
# Training   Loss: 1.327044
# Validation Loss: 1.280234
# Epoch 91
# Training   Loss: 1.328920
# Validation Loss: 1.279274
# Epoch 92
# Training   Loss: 1.323347
# Validation Loss: 1.280848
# Epoch 93
# Training   Loss: 1.329245
# Validation Loss: 1.278317
# Epoch 94
# Training   Loss: 1.330088
# Validation Loss: 1.280873
# Epoch 95
# Training   Loss: 1.329223
# Validation Loss: 1.280420
# Epoch 96
# Training   Loss: 1.334715
# Validation Loss: 1.285395
# Epoch 97
# Training   Loss: 1.335007
# Validation Loss: 1.284390
# Epoch 98
# Training   Loss: 1.333382
# Validation Loss: 1.282857
# Epoch 99
# Training   Loss: 1.334975
# Validation Loss: 1.285069
# Epoch 100
# Training   Loss: 1.333250
# Validation Loss: 1.283868
# Epoch 101
# Training   Loss: 1.332914
# Validation Loss: 1.284464
# Epoch 102
# Training   Loss: 1.331424
# Validation Loss: 1.283478
# Epoch 103
# Training   Loss: 1.333099
# Validation Loss: 1.285691
# Epoch 104
# Training   Loss: 1.333381
# Validation Loss: 1.286398
# Epoch 105
# Training   Loss: 1.332319
# Validation Loss: 1.286018
# Epoch 106
# Training   Loss: 1.326248
# Validation Loss: 1.280294
# Epoch 107
# Training   Loss: 1.328523
# Validation Loss: 1.282970
# Epoch 108
# Training   Loss: 1.323109
# Validation Loss: 1.278888
# Epoch 109
# Training   Loss: 1.324002
# Validation Loss: 1.278822
# Epoch 110
# Training   Loss: 1.324507
# Validation Loss: 1.279709
# Epoch 111
# Training   Loss: 1.322432
# Validation Loss: 1.278980
# Epoch 112
# Training   Loss: 1.323831
# Validation Loss: 1.279456
# Epoch 113
# Training   Loss: 1.323956
# Validation Loss: 1.280129
# Epoch 114
# Training   Loss: 1.322771
# Validation Loss: 1.279604
# Epoch 115
# Training   Loss: 1.323571
# Validation Loss: 1.282162
# Epoch 116
# Training   Loss: 1.324428
# Validation Loss: 1.283413
# Epoch 117
# Training   Loss: 1.318115
# Validation Loss: 1.278984
# Epoch 118
# Training   Loss: 1.325031
# Validation Loss: 1.284816
# Epoch 119
# Training   Loss: 1.323196
# Validation Loss: 1.283602
# Epoch 120
# Training   Loss: 1.325671
# Validation Loss: 1.285189
# Epoch 121
# Training   Loss: 1.325365
# Validation Loss: 1.286481
# Epoch 122
# Training   Loss: 1.327580
# Validation Loss: 1.287633
# Epoch 123
# Training   Loss: 1.327953
# Validation Loss: 1.287351
# Epoch 124
# Training   Loss: 1.327778
# Validation Loss: 1.287934
# Epoch 125
# Training   Loss: 1.328398
# Validation Loss: 1.290257
# Epoch 126
# Training   Loss: 1.324775
# Validation Loss: 1.289572
# Epoch 127
# Training   Loss: 1.325987
# Validation Loss: 1.291812
# Epoch 128
# Training   Loss: 1.332078
# Validation Loss: 1.293038
# Early Stopping

# %% [markdown]
# # Training history

# %%
epoch_number = list(range((loss_train > 0.).sum()))
plt.figure()
plt.plot(epoch_number, loss_train[loss_train>0.],label='Training Loss')
plt.plot(epoch_number, loss_val[loss_train>0.],label='Validation Loss')
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.grid(True)
plt.legend(loc='upper right')
#plt.savefig('%s/ROC.pdf'%(options.outputDir))
plt.show()

# %% [markdown]
# # Building the ROC Curves

# %%
labels = ['gluon', 'quark', 'W', 'Z', 'top']

# %%
lst = []
n_batches_val = int(X_val.size()[0]/batch_size)
if args_cuda:    
    for j in torch.split(X_val, n_batches_val).cuda():
        a = gnn(j).cpu().data.numpy()
        lst.append(a)
else:
    for j in torch.split(X_val, n_batches_val):
        a = gnn(j).cpu().data.numpy()
        lst.append(a)
predicted = Variable(torch.FloatTensor(np.concatenate(lst)))

# %%
# there is no softmax in the output layer. We have to put it by 
predicted = torch.nn.functional.softmax(predicted, dim=1)

# %%
predict_val = predicted.data.numpy()
true_val = y_val.data.numpy()

# %%
from sklearn.metrics import roc_curve, auc
#### get the ROC curves
fpr = {}
tpr = {}
auc1 = {}
plt.figure()
for i, label in enumerate(labels):
        fpr[label], tpr[label], threshold = roc_curve((true_val== i), predict_val[:,i])
        auc1[label] = auc(fpr[label], tpr[label])
        plt.plot(tpr[label],fpr[label],label='%s tagger, auc = %.1f%%'%(label,auc1[label]*100.))
plt.semilogy()
plt.xlabel("sig. efficiency")
plt.ylabel("bkg. mistag rate")
plt.ylim(0.001,1)
plt.grid(True)
plt.legend(loc='lower right')
#plt.savefig('%s/ROC.pdf'%(options.outputDir))
plt.show()
